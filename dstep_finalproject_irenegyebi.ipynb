# %% [markdown]
# # Examining the relationship between H1-B Visa Policies and Occupational Employment Trends in STEM Fields.
#
# ---
#
# 1. Problem Statement
# 2. Background and Objectives
# 3. Dataset Description
#
# ---
#
#
# ![nextsource.com(March 5, 2021/Kyle Torti
# )](https://www.nextsource.com/wp-content/uploads/2021/03/h1b-visa.jpg)
#
# ### Problem Statement
#
# The technology sector in the United States relies heavily on high-skilled foreign workers to fill talent gaps, particularly in science, technology, engineering and math (STEM) occupations. The H1-B visa program allows U.S. companies to temporarily employ foreign workers in specialty occupations. However, the H1-B visa cap limits the number of foreign workers that can be hired each year. At the same time, employment in many STEM occupations has steadily increased over the past decade. This raises important policy questions about the relationship between H1-B visa policies and the supply of high-skilled STEM workers in the U.S.
#
# This project aims to investigate and understand the complex relationship between H1-B visa policies and occupational employment patterns within STEM fields using HI-B disclosure data (2014-2022) from [the Office of Foreign Labor Certification](https://www.dol.gov/agencies/eta/foreign-labor/performance)**(OFLC)** and Occupational and Wage Statistics data from the [Bureau of Labor Statistics](https://www.bls.gov/oes/tables.htm)(BLS). Examining these historical datasets would provide insights into how visa policies aimed at supplying skilled technical talent relate to changing labor market demands.
#
#
# ### Background
#
# The United States has historically attracted a significant number of highly skilled immigrants in Science, Technology, Engineering, and Mathematics (STEM) fields through the H1-B visa program. The H1-B visa program, administered by the U.S. Citizenship and Immigration Services (USCIS), allows U.S. employers to hire foreign workers in specialized occupations, often filling gaps in the domestic labor force and contributing to the innovation and competitiveness of the U.S. economy. However, the program has undergone various policy shifts and reforms aimed at protecting the interests of American workers, addressing skills shortages, and maintaining national security. These policy changes including alterations in visa allocation methods, wage requirements, and limitations on visa duration, among others, have the potential to impact occupational employment trends in the STEM sectors. Understanding the relationship between H1-B visa policies and STEM occupational employment trends could inform future policy decisions regarding optimal H1-B visa levels to support innovation and employment growth in critical STEM fields.
#
# **Objectives**
#
# Some potential questions to be addressed include:
# 1. What are the historical policy changes and regulations in the H1-B visa program, and how have they impacted the issuance and utilization of H1-B visas in STEM fields?
#
# 2. What are the current occupational employment trends in STEM fields in terms of job growth, wages, and demand for labor in the United States?
#
# 3. Is there a discernible relationship between H1-B visa policy changes and occupational employment trends in STEM fields? If so, how do these policy changes correlate with employment patterns, including job growth, wage levels, and labor market competitiveness in STEM occupations?
#
# 4. What are the potential economic, societal, and innovation-related implications of the observed relationships between H1-B visa policies and STEM employment trends?
#
# 5. Do current H1-B visa caps align with the growth in demand for high-skilled STEM occupations? How do shifts in H1-B policy impact occupational employment trends in key technology jobs over time?
#
# 6. How has the number and share of H1b workers changed over time in different STEM occupations and industries?
#
# 7. Identify trends in the issuance of H1-B visas and their correlation with the availability and demand for STEM jobs.
#
# This project can provide valuable insights for employers, job seekers, educators, and stakeholders in STEM-related industries, contributing to informed decision-making in an ever-evolving labor market.
#
#
# ### Dataset Description
#
# #### H1-B Disclosure data (OFLC)
#
# The H-1B program allows companies in the United States to temporarily employ foreign workers in specialty occupations. As part of the requirements of the program, companies must disclose information about the H-1B employees they sponsor, including details like the employee's job title, salary, work location, and more. This disclosure data provides valuable insights into how companies utilize the H-1B program.
#
# "Disclosure data consists of selected information extracted from nonimmigrant and immigrant application tables within the Office of Foreign Labor Certification's case management systems. The data sets provide public access to the latest quarterly and annual data in easily accessible formats for the purpose of performing in-depth longitudinal research and analysis. Each data set is cumulative for the fiscal year, containing unique records identified by the applicable OFLC case number based on the most recent date a case determination decision was issued. Information that appears in these records is provided by employers and system-generated metadata, such as received dates and decision dates. Any typographical errors or other data anomalies (e.g., incomplete or blank data fields, etc.) may be due to internal data entry or other external customer errors in completing and submitting the applications for processing" [OFLC](https://www.dol.gov/agencies/eta/foreign-labor/performance).
#
#
# **Data Dictionary:** <br>
#
# **Field Name**          |**Description**
# :-----------------------|:---------------------------------------------------------------------------------------------------------------------------------------
# Submitted_Date          |Date and time the application was submitted
# Employer Name           |Employer's name
# City                    |Employer's city
# State                   |Employer's state
# Nbr_Immigrants          |Number of job openings
# Job_Title               |Job title
# Dol_Decision_Date       |Date certified or denied
# Occupation_Code         |Three digit occupational group-see appendix 1 of ETA Form 9035 for the complete list
# Occupational_Title      |Title of three digit occupation group
# Approval_Status         |Approval status - certified or denied
# Wage_Rate_1             |Employer's proposed wage rate
# Rate_Per_1              |Unit of pay for proposed wage rate
# Part_Time_1             |Y = Part time; N = Full time position
# City_1                  |Work city (location of the job opening)
# State_1                 |Work state (location of the job opening)
# Prevailing_Wage_1       |Prevailing wage rate
# Wage_Source_1           |Collective bargining; SESA; Other
#
#
# #### Occupational and Wage Statistics data (BLS)
#
# The Occupational Employment and Wage Statistics (OEWS) program at the Bureau of Labor Statistics produces employment and wage estimates for over 830 occupations. Data is collected from a semi-annual mail survey of non-farm establishments, providing key insights into the state of the labor market. The OEWS survey generates information on the number of workers in given occupations along with percentiles of their wage distributions. This allows for an understanding of employment levels and earning potentials across different jobs [BLS](https://www.bls.gov/oes/).
#
# **Data Dictionary:** <br>
#
# **Field**  |**Field Description**
# :----------|:-----------------------------------------------------------------------------------------------------------------------------------------
# area       |The MSA code or the State fips code
# st         |The State abbreviation (only on the State file)
# state      |The State name (only on the State file)
# occ_code   |The 7-digit Standard Occupational Classification (SOC) code for the occupation
# occ_title  |The Standard Occupational Classification title for the occupation
# group      |Contains "major" if this is a SOC major group occupation, otherwise this column is blank
# tot_emp    |The estimated total employment rounded to the nearest 10 (excludes self-employed)
# emp_prse ¹ |The percent relative standard error for the employment
# jobs_1000  |The number of jobs (employment) in the given occupation per 1,000 jobs in the given area (only on the statewide, metropolitan, and nonmetropolitan statistical area files)
# h_mean     |The mean hourly wage
# a_mean     |The mean annual wage
# mean_prse ¹|The percent relative standard error for the mean wage
# h_pct10    |The hourly 10th percentile wage
# h_pct25    |The hourly 25th percentile wage
# h_median   |The hourly median wage (or the 50th percentile)
# h_pct75    |The hourly 75th percentile wage
# h_pct90    |The hourly 90th percentile wage
# a_pct10    |The annual 10th percentile wage
# a_pct25    |The annual 25th percentile wage
# a_median   |The annual median wage (or the 50th percentile)
# a_pct75    |The annual 75th percentile wage
# a_pct90    |The annual 90th percentile wage
#
# `Notes:`
# * Relative Standard Error (RSE) is a measure of the reliability of a statistic; the smaller the relative standard error, the more precise the estimate.
# * Percents do not total to 100 due to occupational data not reported.
# * `*` indicates that a wage estimate is not available
# * `**` indicates that an employment estimate is not available
# * `#` indicates a wage greater than $80.00 per hour or $166,400 per year
# * `~` indicates that the percent of establishments reporting the occupation is less than 0.5%

# %% [markdown]
# ## **Exploratory Data Analysis**
#
# ---
#
# 1. Import packages
# 2. Loading data with Pandas
# 3. Data Cleaning
# 4. Descriptive statistics of data
# 5. Data visualization
# 6. Hypothesis investigation
#
# ---
#
# ### **1. Import packages**

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# Shows plots in jupyter notebook
# %matplotlib inline

# Set plot style
sns.set(color_codes=True)

# %% [markdown]
# ## **2. Loading data with Pandas**
#
# Load `H1-B datasets from OFLC` and `Occupational Statistics dataset from BLS` into individual dataframes so that we can work with them in Python. We will be working with data from `2008-2022`.
#
# Ps. I started exploring only data for 2008.

# %%
# load H1B data
h1b=pd.read_excel('https://www.dol.gov/sites/dolgov/files/ETA/oflc/pdfs/H-1B_Case_Data_FY2008.xlsx')

# load bls data
bls=pd.read_excel('../../../Downloads/Documents/Dstep/oesm08st/state.xls')

# %% [markdown]
# Let's look at the first 3 rows and get a concise summary of both dataframes to see what the data looks like.

# %%
h1b.head(3) #first 3 rows
# Out:
#   SUBMITTED_DATE          CASE_NO PROGRAM  \
# 0     2008-03-30  I-08090-4182485       R
# 1     2008-03-30  I-08090-4182487       R
# 2     2008-03-30  I-08090-4182493       R
#
#                                          NAME                       ADDRESS1  \
# 0  SPI RESEARCH AND DEVELOPMENT SERVICES, LLC        67 SOUTH BEDFORD STREET
# 1               Nexus Software Solutions,Inc.  200 Lakeside Drive, Suite 228
# 2                                GREYCELL INC               3830 VILLAGE TER
#
#     ADDRESS2        CITY STATE  POSTAL_CODE  NBR_IMMIGRANTS  ... MAX_RATE_2  \
# 0      205 W  BURLINGTON    MA         1803               1  ...        NaN
# 1        NaN     Horsham    PA        19044               1  ...        NaN
# 2  SUITE 241     FREMONT    CA        94536               1  ...        NaN
#
#   PART_TIME_2 CITY_2 STATE_2  PREVAILING_WAGE_2  WAGE_SOURCE_2  \
# 0         NaN    NaN     NaN                NaN            NaN
# ...

# %%
h1b.shape #get the shape of the data
# Out:
# (405641, 40)

# %% [markdown]
# **Observation(s):**
# * With the H1-B data, we have a mix of numeric and categorical data as well.
# * We also have a lot of Missing data which we would have to clean.
# * There are 40 columns in the dataset (not all of them is necessary for our analysis and would need to be dropped).

# %%
bls.head(3)
# Out:
#    AREA  ST    STATE OCC_CODE               OCC_TITLE  GROUP  TOT_EMP  \
# 0     1  AL  Alabama  00-0000         All Occupations    NaN  1945300
# 1     1  AL  Alabama  11-0000  Management occupations  major    79400
# 2     1  AL  Alabama  11-1011        Chief executives    NaN     3630
#
#   EMP_PRSE H_MEAN  A_MEAN  ... H_MEDIAN H_PCT75 H_PCT90 A_PCT10 A_PCT25  \
# 0      0.4  17.39   36170  ...    13.53   21.19   31.23   14820   18970
# 1      0.9  42.41   88210  ...    36.75   52.02   75.47   38690   54430
# 2      3.7  75.62  157290  ...    73.07       #       #   65680  100680
#
#   A_MEDIAN A_PCT75 A_PCT90 ANNUAL HOURLY
# 0    28140   44070   64950    NaN    NaN
# 1    76450  108210  156970    NaN    NaN
# 2   151990       #       #    NaN    NaN
#
# [3 rows x 23 columns]

# %%
bls.shape #get the shape of the data
# Out:
# (36765, 23)

# %% [markdown]
# **Observation(s):**
# * Similar to the H1-B data, we have a mix of numeric and categorical data, Missing data and unneccesary columns that needs to be cleaned.

# %% [markdown]
# ---
#
# ## 3. Data Cleaning
#
#
# #### Drop Unnecessary Columns

# %%
# drop columns from h1b data
h1b_df=h1b.drop(columns=['WAGE_RATE_2','RATE_PER_2','MAX_RATE_2','PART_TIME_2','PREVAILING_WAGE_2','WAGE_SOURCE_2','YR_SOURCE_PUB_2','OTHER_WAGE_SOURCE_2','CITY_2', 'STATE_2',
                        'PROGRAM','CASE_NO','ADDRESS1','ADDRESS2','POSTAL_CODE','BEGIN_DATE','END_DATE','CERTIFIED_BEGIN_DATE','CERTIFIED_END_DATE','WITHDRAWN','YR_SOURCE_PUB_1',
                        'OTHER_WAGE_SOURCE_1','JOB_CODE','MAX_RATE_1'])

#check remaining columns
h1b_df.columns
# Out:
# Index(['SUBMITTED_DATE', 'NAME', 'CITY', 'STATE', 'NBR_IMMIGRANTS',
#        'JOB_TITLE', 'DOL_DECISION_DATE', 'APPROVAL_STATUS', 'WAGE_RATE_1',
#        'RATE_PER_1', 'PART_TIME_1', 'CITY_1', 'STATE_1', 'PREVAILING_WAGE_1',
#        'WAGE_SOURCE_1', 'OCCUPATIONAL_TITLE'],
#       dtype='object')

# %%
h1b_df.shape #shape of data
# Out:
# (405641, 16)

# %%
# drop columns from h1b data
bls_df=bls.drop(columns=['ANNUAL','HOURLY'])

#check remaining columns
bls_df.columns
# Out:
# Index(['AREA', 'ST', 'STATE', 'OCC_CODE', 'OCC_TITLE', 'GROUP', 'TOT_EMP',
#        'EMP_PRSE', 'H_MEAN', 'A_MEAN', 'MEAN_PRSE', 'H_PCT10', 'H_PCT25',
#        'H_MEDIAN', 'H_PCT75', 'H_PCT90', 'A_PCT10', 'A_PCT25', 'A_MEDIAN',
#        'A_PCT75', 'A_PCT90'],
#       dtype='object')

# %%
bls_df.shape #shape of data
# Out:
# (36765, 21)

# %% [markdown]
# #### Missing Data

# %%
#Total missing values for each column
h1b_df.isnull().sum()
# Out:
# SUBMITTED_DATE          0
# NAME                    0
# CITY                    0
# STATE                   0
# NBR_IMMIGRANTS          0
# JOB_TITLE               0
# DOL_DECISION_DATE       0
# APPROVAL_STATUS         0
# WAGE_RATE_1             0
# RATE_PER_1              0
# PART_TIME_1             0
# CITY_1                  0
# STATE_1                 0
# PREVAILING_WAGE_1       0
# WAGE_SOURCE_1           0
# OCCUPATIONAL_TITLE    642
# dtype: int64

# %%
# define a function for replacing missing values (categorical columns)
def replace_missing_values(dataframe, column, replacement_value):
    dataframe[column].fillna(replacement_value, inplace=True)

# %%
replace_missing_values(h1b_df,'OCCUPATIONAL_TITLE', 'Not_Stated')

# %%
h1b_df.isnull().sum()
# Out:
# SUBMITTED_DATE        0
# NAME                  0
# CITY                  0
# STATE                 0
# NBR_IMMIGRANTS        0
# JOB_TITLE             0
# DOL_DECISION_DATE     0
# APPROVAL_STATUS       0
# WAGE_RATE_1           0
# RATE_PER_1            0
# PART_TIME_1           0
# CITY_1                0
# STATE_1               0
# PREVAILING_WAGE_1     0
# WAGE_SOURCE_1         0
# OCCUPATIONAL_TITLE    0
# dtype: int64

# %%
bls_df.isnull().sum()
# Out:
# AREA             0
# ST               0
# STATE            0
# OCC_CODE         0
# OCC_TITLE        0
# GROUP        35580
# TOT_EMP          0
# EMP_PRSE         0
# H_MEAN           0
# A_MEAN           0
# MEAN_PRSE        0
# H_PCT10          0
# H_PCT25          0
# H_MEDIAN         0
# H_PCT75          0
# H_PCT90          0
# A_PCT10          0
# A_PCT25          0
# A_MEDIAN         0
# A_PCT75          0
# A_PCT90          0
# dtype: int64

# %%
replace_missing_values(bls_df,'GROUP', 'not_major')

# %%
h1b_df.isnull().sum()
# Out:
# SUBMITTED_DATE        0
# NAME                  0
# CITY                  0
# STATE                 0
# NBR_IMMIGRANTS        0
# JOB_TITLE             0
# DOL_DECISION_DATE     0
# APPROVAL_STATUS       0
# WAGE_RATE_1           0
# RATE_PER_1            0
# PART_TIME_1           0
# CITY_1                0
# STATE_1               0
# PREVAILING_WAGE_1     0
# WAGE_SOURCE_1         0
# OCCUPATIONAL_TITLE    0
# dtype: int64

# %% [markdown]
# We have dropped all unnecessary columns and cleaned missing data for both datasets. We will now look at some descriptive statistics.

# %% [markdown]
# ---
#
# ## 3. Descriptive statistics of data
#
# ### Data types
#
# It is useful to first understand the data that you're dealing with along with the data types of each column. The data types may dictate how you transform and engineer features.

# %%
h1b_df.info() #concise summary
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 405641 entries, 0 to 405640
# Data columns (total 16 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   SUBMITTED_DATE      405641 non-null  datetime64[ns]
#  1   NAME                405641 non-null  object
#  2   CITY                405641 non-null  object
#  3   STATE               405641 non-null  object
#  4   NBR_IMMIGRANTS      405641 non-null  int64
#  5   JOB_TITLE           405641 non-null  object
#  6   DOL_DECISION_DATE   405641 non-null  datetime64[ns]
#  7   APPROVAL_STATUS     405641 non-null  object
#  8   WAGE_RATE_1         405641 non-null  float64
#  9   RATE_PER_1          405641 non-null  object
#  10  PART_TIME_1         405641 non-null  object
#  11  CITY_1              405641 non-null  object
#  12  STATE_1             405641 non-null  object
#  13  PREVAILING_WAGE_1   405641 non-null  float64
#  14  WAGE_SOURCE_1       405641 non-null  object
# ...

# %%
bls_df.info() #concise summary
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36765 entries, 0 to 36764
# Data columns (total 21 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   AREA       36765 non-null  int64
#  1   ST         36765 non-null  object
#  2   STATE      36765 non-null  object
#  3   OCC_CODE   36765 non-null  object
#  4   OCC_TITLE  36765 non-null  object
#  5   GROUP      36765 non-null  object
#  6   TOT_EMP    36765 non-null  object
#  7   EMP_PRSE   36765 non-null  object
#  8   H_MEAN     36765 non-null  object
#  9   A_MEAN     36765 non-null  object
#  10  MEAN_PRSE  36765 non-null  object
#  11  H_PCT10    36765 non-null  object
#  12  H_PCT25    36765 non-null  object
#  13  H_MEDIAN   36765 non-null  object
#  14  H_PCT75    36765 non-null  object
#  15  H_PCT90    36765 non-null  object
#  16  A_PCT10    36765 non-null  object
#  17  A_PCT25    36765 non-null  object
#  18  A_MEDIAN   36765 non-null  object
# ...

# %% [markdown]
# We can see that all of the `datetime` related columns are in datetime format. No need to convert these later.

# %% [markdown]
# ### Statistics
#
# Now let's look at some statistics about the datasets.

# %%
h1b_df.describe()
# Out:
#        NBR_IMMIGRANTS   WAGE_RATE_1  PREVAILING_WAGE_1
# count   405641.000000  4.056410e+05       4.056410e+05
# mean         1.758732  7.708609e+04       5.761739e+04
# std          7.303955  2.354900e+06       9.204500e+05
# min          1.000000  1.000000e+00       0.000000e+00
# 25%          1.000000  4.700000e+04       4.207800e+04
# 50%          1.000000  5.851000e+04       5.252000e+04
# 75%          1.000000  7.500000e+04       6.554100e+04
# max        839.000000  5.218700e+08       5.025300e+08

# %%
bls_df.describe()
# Out:
#                AREA
# count  36765.000000
# mean      30.191786
# std       16.922094
# min        1.000000
# 25%       17.000000
# 50%       30.000000
# 75%       44.000000
# max       78.000000

# %% [markdown]
# ---
#
# ## 4. Data visualization
#
# Now let's look at some basic visualizations

# %%
# Define a function for creating histograms for Numeric columns

def create_histograms(dataframe):
    # Select numeric columns
    numeric_columns = dataframe.select_dtypes(include=np.number).columns
    
    # Plot histograms for each numeric column
    for column in numeric_columns:
        plt.figure(figsize=(8, 6))
        plt.hist(dataframe[column], bins='auto', color='#0504aa', alpha=0.7, rwidth=0.85)
        plt.title(f'Histogram of {column}')
        plt.xlabel(column)
        plt.ylabel('Frequency')
        plt.grid(axis='y', linestyle='--', alpha=0.7)
        plt.show()

# %%
create_histograms(h1b_df)

# %%
create_histograms(bls_df)

# %%
plt.figure(figsize=(18,30))
h1b_df['OCCUPATIONAL_TITLE'].value_counts(ascending=True).plot(kind='barh', color='#0504aa', alpha=0.7)
plt.title('Bar Chart of OCCUPATIONAL_TITLE', fontsize=25)
plt.xlabel('OCCUPATIONAL_TITLE')
plt.ylabel('Count')
#plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.show()

# %%
plt.figure(figsize=(8,6))
h1b_df['PART_TIME_1'].value_counts(ascending=True).plot(kind='bar', color='#0504aa', alpha=0.7)
plt.title('Bar Chart of PART_TIME_1', fontsize=15)
plt.xlabel('PART_TIME_1')
plt.ylabel('Count')
plt.xticks(rotation=360)  # Rotate x-axis labels for better readability
plt.show()
